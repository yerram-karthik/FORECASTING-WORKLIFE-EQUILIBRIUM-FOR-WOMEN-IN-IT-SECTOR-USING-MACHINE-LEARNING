# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as m
import seaborn as s
# %matplotlib inline

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import  confusion_matrix, classification_report, accuracy_score, log_loss

# %%
s.set_style("darkgrid")
m.rcParams['font.size'] = 14
m.rcParams['figure.figsize'] = (9, 5)
m.rcParams['figure.facecolor'] = '#00000000'

# %%
train_raw = p.read_csv('Train.csv', delimiter = ';')
train_raw
# Out:
#        EmployeeID  Target   Age  AvgDailyHours              Department  \
# 0          100001       0  36.0           6.45                   Sales
# 1          100002       0  24.0           8.48                   Sales
# 2          100003       0  45.0           6.93  Research & Development
# 3          100004       1  29.0           7.10                   Sales
# 4          100005       0  30.0           7.30         Human Resources
# ...           ...     ...   ...            ...                     ...
# 15995      115996       0  19.0           6.81                   Sales
# 15996      115997       0  56.0           7.60                   Sales
# 15997      115998       0  26.0           6.52         Human Resources
# 15998      115999       0  29.0           6.11  Research & Development
# 15999      116000       0  41.0          10.03         Human Resources
#
#        Education    EducationField  Gender HasFlexibleTimings  \
# 0              5  Technical Degree    Male                 No
# 1              5  Technical Degree    Male                 No
# 2              2  Technical Degree  Female                 No
# 3              4           Medical    Male                 No
# 4              3     Life Sciences  Female                 No
# ...          ...               ...     ...                ...
# 15995          2             Other    Male                Yes
# 15996          2  Technical Degree  Female                 No
# 15997          1             Other  Female                 No
# 15998          4   Human Resources  Female                Yes
# 15999          3   Human Resources    Male                 No
#
#       IsIndividualContributor  ...  RelationshipSatisfaction  \
# 0                         Yes  ...                         1
# 1                         Yes  ...                         1
# 2                         Yes  ...                         4
# 3                          No  ...                         4
# 4                         Yes  ...                         1
# ...                       ...  ...                       ...
# 15995                     Yes  ...                         3
# 15996                      No  ...                         2
# 15997                     Yes  ...                         3
# 15998                      No  ...                         1
# 15999                      No  ...                         2
#
#       RemoteWorkSatistfaction  SelfMotivationLevel  TotalWorkingYears  \
# 0                      Medium                    3                8.0
# 1                   Very High                    2                1.0
# 2                        High                    1               17.0
# 3                      Medium                    2                2.0
# 4                   Very High                    4                9.0
# ...                       ...                  ...                ...
# 15995                    High                    2                0.0
# 15996                     Low                    2                7.0
# 15997                    High                    4                5.0
# 15998                    High                    2                6.0
# 15999                  Medium                    3               18.0
#
#       TrainingTimesLastYear  WorkLifeBalance  WorkLoadLevel  YearsAtCompany  \
# 0                         2                2            Low             8.0
# 1                         5                2           High             0.0
# 2                         6                4            Low            17.0
# 3                         0                2            NaN             1.0
# 4                         6                1         Medium             3.0
# ...                     ...              ...            ...             ...
# 15995                     3                1            NaN             0.0
# 15996                     2                1         Medium             6.0
# 15997                     3                4           High             1.0
# 15998                     3                1           High             1.0
# 15999                     3                3           High             0.0
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# 0                          1.0                   8.0
# 1                          0.0                   0.0
# 2                          4.0                  10.0
# 3                          1.0                   1.0
# 4                          3.0                   0.0
# ...                        ...                   ...
# 15995                      0.0                   0.0
# 15996                      2.0                   2.0
# 15997                      1.0                   1.0
# 15998                      1.0                   1.0
# 15999                      0.0                   0.0
#
# [16000 rows x 30 columns]

# %%
train_raw[(train_raw.PerformanceRating == n.int64(4))].JobSatisfaction.value_counts()
# Out:
# 4    1009
# 1    1006
# 2     984
# 3     961
# Name: JobSatisfaction, dtype: int64

# %%
train_raw.columns
# Out:
# Index(['EmployeeID', 'Target', 'Age', 'AvgDailyHours', 'Department',
#        'Education', 'EducationField', 'Gender', 'HasFlexibleTimings',
#        'IsIndividualContributor', 'JobInvolvement', 'JobRole',
#        'JobSatisfaction', 'LeavesTaken', 'MaritalStatus', 'MicromanagedAtWork',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction',
#        'RemoteWorkSatistfaction', 'SelfMotivationLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'WorkLoadLevel',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
s.heatmap(train_raw.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
train_raw.isnull().sum(axis=0)
# Out:
# EmployeeID                    0
# Target                        0
# Age                         607
# AvgDailyHours                 0
# Department                    0
# Education                     0
# EducationField                0
# Gender                      348
# HasFlexibleTimings          169
# IsIndividualContributor     325
# JobInvolvement                0
# JobRole                     370
# JobSatisfaction               0
# LeavesTaken                  49
# MaritalStatus               234
# MicromanagedAtWork          138
# MonthlyIncome                 0
# NumCompaniesWorked            0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# RemoteWorkSatistfaction       0
# SelfMotivationLevel           0
# TotalWorkingYears           333
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# WorkLoadLevel               413
# YearsAtCompany              333
# YearsSinceLastPromotion     333
# YearsWithCurrManager        333
# dtype: int64

# %%
train_raw.describe()
# Out:
#           EmployeeID        Target           Age  AvgDailyHours     Education  \
# count   16000.000000  16000.000000  15393.000000   16000.000000  16000.000000
# mean   108000.500000      0.176250     38.966413       7.768878      3.001313
# std      4618.946489      0.381045     12.365318       1.827135      1.410916
# min    100001.000000      0.000000     18.000000       2.000000      1.000000
# 25%    104000.750000      0.000000     28.000000       6.660000      2.000000
# 50%    108000.500000      0.000000     39.000000       7.400000      3.000000
# 75%    112000.250000      0.000000     50.000000       8.490000      4.000000
# max    116000.000000      1.000000     60.000000      18.340000      5.000000
#
#        JobInvolvement  JobSatisfaction   LeavesTaken  MicromanagedAtWork  \
# count    16000.000000     16000.000000  15951.000000        15862.000000
# mean         2.509063         2.494937     10.914175            3.001954
# std          1.122329         1.116211      6.449444            1.413566
# min          1.000000         1.000000      2.000000            1.000000
# 25%          2.000000         1.000000      6.000000            2.000000
# 50%          3.000000         2.000000      9.000000            3.000000
# 75%          4.000000         3.000000     15.000000            4.000000
# max          4.000000         4.000000     30.000000            5.000000
#
#        MonthlyIncome  ...  PercentSalaryHike  PerformanceRating  \
# count   1.600000e+04  ...       16000.000000       16000.000000
# mean    2.280443e+05  ...          16.003000           2.493875
# std     6.733454e+05  ...           5.488681           1.116934
# min     1.017000e+03  ...           7.000000           1.000000
# 25%     3.333300e+04  ...          11.000000           1.000000
# 50%     1.250000e+05  ...          16.000000           2.000000
# 75%     2.416670e+05  ...          21.000000           3.000000
# max     7.916670e+06  ...          25.000000           4.000000
#
#        RelationshipSatisfaction  SelfMotivationLevel  TotalWorkingYears  \
# count              16000.000000         16000.000000       15667.000000
# mean                   2.494687             2.488000           9.205464
# std                    1.118559             1.118228           8.885191
# min                    1.000000             1.000000           0.000000
# 25%                    1.000000             1.000000           2.000000
# 50%                    2.000000             2.000000           6.000000
# 75%                    3.000000             3.000000          15.000000
# max                    4.000000             4.000000          39.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count           16000.000000     16000.000000    15667.000000
# mean                3.004313         2.499125        4.557669
# std                 2.003352         1.113026        5.864989
# min                 0.000000         1.000000        0.000000
# 25%                 1.000000         2.000000        0.000000
# 50%                 3.000000         2.000000        2.000000
# 75%                 5.000000         3.000000        7.000000
# max                 6.000000         4.000000       38.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count             15667.000000          15667.000000
# mean                  1.785792              2.017872
# std                   1.695834              2.441463
# min                   0.000000              0.000000
# 25%                   0.000000              0.000000
# 50%                   1.000000              1.000000
# 75%                   3.000000              3.000000
# max                   5.000000             10.000000
#
# [8 rows x 21 columns]

# %%
train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                16000 non-null  int64
#  1   Target                    16000 non-null  int64
#  2   Age                       15393 non-null  float64
#  3   AvgDailyHours             16000 non-null  float64
#  4   Department                16000 non-null  object
#  5   Education                 16000 non-null  int64
#  6   EducationField            16000 non-null  object
#  7   Gender                    15652 non-null  object
#  8   HasFlexibleTimings        15831 non-null  object
#  9   IsIndividualContributor   15675 non-null  object
#  10  JobInvolvement            16000 non-null  int64
#  11  JobRole                   15630 non-null  object
#  12  JobSatisfaction           16000 non-null  int64
#  13  LeavesTaken               15951 non-null  float64
#  14  MaritalStatus             15766 non-null  object
#  15  MicromanagedAtWork        15862 non-null  float64
#  16  MonthlyIncome             16000 non-null  int64
#  17  NumCompaniesWorked        16000 non-null  int64
#  18  PercentSalaryHike         16000 non-null  int64
#  19  PerformanceRating         16000 non-null  int64
#  20  RelationshipSatisfaction  16000 non-null  int64
#  21  RemoteWorkSatistfaction   16000 non-null  object
#  22  SelfMotivationLevel       16000 non-null  int64
#  23  TotalWorkingYears         15667 non-null  float64
#  24  TrainingTimesLastYear     16000 non-null  int64
#  25  WorkLifeBalance           16000 non-null  int64
#  26  WorkLoadLevel             15587 non-null  object
#  27  YearsAtCompany            15667 non-null  float64
#  28  YearsSinceLastPromotion   15667 non-null  float64
#  29  YearsWithCurrManager      15667 non-null  float64
# dtypes: float64(8), int64(13), object(9)
# memory usage: 3.7+ MB

# %%
df = train_raw.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13554 entries, 0 to 15999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                13554 non-null  int64
#  1   Target                    13554 non-null  int64
#  2   Age                       13554 non-null  float64
#  3   AvgDailyHours             13554 non-null  float64
#  4   Department                13554 non-null  object
#  5   Education                 13554 non-null  int64
#  6   EducationField            13554 non-null  object
#  7   Gender                    13554 non-null  object
#  8   HasFlexibleTimings        13554 non-null  object
#  9   IsIndividualContributor   13554 non-null  object
#  10  JobInvolvement            13554 non-null  int64
#  11  JobRole                   13554 non-null  object
#  12  JobSatisfaction           13554 non-null  int64
#  13  LeavesTaken               13554 non-null  float64
#  14  MaritalStatus             13554 non-null  object
#  15  MicromanagedAtWork        13554 non-null  float64
#  16  MonthlyIncome             13554 non-null  int64
#  17  NumCompaniesWorked        13554 non-null  int64
#  18  PercentSalaryHike         13554 non-null  int64
#  19  PerformanceRating         13554 non-null  int64
#  20  RelationshipSatisfaction  13554 non-null  int64
#  21  RemoteWorkSatistfaction   13554 non-null  object
#  22  SelfMotivationLevel       13554 non-null  int64
#  23  TotalWorkingYears         13554 non-null  float64
#  24  TrainingTimesLastYear     13554 non-null  int64
#  25  WorkLifeBalance           13554 non-null  int64
#  26  WorkLoadLevel             13554 non-null  object
#  27  YearsAtCompany            13554 non-null  float64
#  28  YearsSinceLastPromotion   13554 non-null  float64
#  29  YearsWithCurrManager      13554 non-null  float64
# dtypes: float64(8), int64(13), object(9)
# memory usage: 3.2+ MB

# %% [markdown]
# ## Visualizing data for a better insight

# %%
m.figure(figsize=(8,5))
m.title('Number of Employees under Stress')
s.countplot(x = df.Target)
# Out:
# <AxesSubplot:title={'center':'Number of Employees under Stress'}, xlabel='Target', ylabel='count'>

# %%
m.figure(figsize=(10,8))
m.title('Age vs Education')

s.boxplot(train_raw.Education, train_raw.Age, hue=train_raw.Target)
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:title={'center':'Age vs Education'}, xlabel='Education', ylabel='Age'>

# %%
m.figure(figsize=(10,8))
m.title('Job Satisfaction vs Education Field')
s.boxplot(train_raw.EducationField, train_raw.JobSatisfaction, hue=train_raw.Target)
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:title={'center':'Job Satisfaction vs Education Field'}, xlabel='EducationField', ylabel='JobSatisfaction'>

# %%
m.figure(figsize=(10,8))
m.title('Average Daily Hours vs Has Flexible Timings')
s.boxplot(train_raw.HasFlexibleTimings, train_raw.AvgDailyHours, hue=train_raw.Target)
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:title={'center':'Average Daily Hours vs Has Flexible Timings'}, xlabel='HasFlexibleTimings', ylabel='AvgDailyHours'>

# %%
s.distplot(df['JobSatisfaction'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Density'>

# %%
s.distplot(df['Education'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
s.distplot(df['Age'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
s.distplot(df['YearsAtCompany'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %%
m.figure(figsize=(10,8))
m.title('Job Involvement vs IsIndividualContributor')
s.boxplot(train_raw.IsIndividualContributor, train_raw.JobInvolvement, hue=train_raw.Target)
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:title={'center':'Job Involvement vs IsIndividualContributor'}, xlabel='IsIndividualContributor', ylabel='JobInvolvement'>

# %%
s.distplot(df['YearsSinceLastPromotion'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
s.distplot(df['YearsWithCurrManager'])
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Density'>

# %% [markdown]
# ## Defining Utility Functions

# %%
def Data_Processor(temp_frame):
    
    from sklearn.preprocessing import LabelEncoder
    label_encoder = LabelEncoder()
    temp = p.DataFrame()
    temp_frame['HasFlexibleTimings']= label_encoder.fit_transform(temp_frame['HasFlexibleTimings']) 
    temp_frame['IsIndividualContributor']= label_encoder.fit_transform(temp_frame['IsIndividualContributor']) 
    temp_frame['RemoteWorkSatistfaction']= label_encoder.fit_transform(temp_frame['RemoteWorkSatistfaction']) 
    temp_frame['WorkLoadLevel']= label_encoder.fit_transform(temp_frame['WorkLoadLevel']) 
    temp = p.concat([p.get_dummies(temp_frame[col]) for col in ['Department','EducationField', 'Gender', 'JobRole', 'MaritalStatus']], axis=1)
    temp.groupby(level=0, axis=1).sum()
    temp_frame = p.concat([temp_frame, temp], axis=1)
    temp_frame.drop(['Department','EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'EmployeeID'], axis=1, inplace=True)

    return temp_frame;

# %%
def Normalize(df):
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    frame = p.DataFrame();
    frame = df
    frame.loc[:, ['Age', 'AvgDailyHours','LeavesTaken', 'MonthlyIncome', 
           'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany', 'YearsWithCurrManager']] = scaler.fit_transform(frame.loc[:, ['Age', 'AvgDailyHours','LeavesTaken', 'MonthlyIncome', 
           'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany', 'YearsWithCurrManager']]);
    return frame;

# %%
df = Data_Processor(df)
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#        Target   Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 0           0  36.0           6.45          5                   0
# 1           0  24.0           8.48          5                   0
# 2           0  45.0           6.93          2                   0
# 4           0  30.0           7.30          3                   0
# 5           0  31.0          10.78          2                   1
# ...       ...   ...            ...        ...                 ...
# 15994       0  24.0           7.32          2                   0
# 15996       0  56.0           7.60          2                   0
# 15997       0  26.0           6.52          1                   0
# 15998       0  29.0           6.11          4                   1
# 15999       0  41.0          10.03          3                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 0                            1               1                2          7.0
# 1                            1               1                4          9.0
# 2                            1               3                4         24.0
# 4                            1               2                4          9.0
# 5                            1               4                4         11.0
# ...                        ...             ...              ...          ...
# 15994                        0               4                4         18.0
# 15996                        0               2                3         14.0
# 15997                        1               4                4          7.0
# 15998                        0               4                2          8.0
# 15999                        0               4                2          4.0
#
#        MicromanagedAtWork  ...  Laboratory Technician  Manager  \
# 0                     3.0  ...                      0        0
# 1                     4.0  ...                      0        0
# 2                     4.0  ...                      0        0
# 4                     5.0  ...                      0        0
# 5                     3.0  ...                      0        0
# ...                   ...  ...                    ...      ...
# 15994                 1.0  ...                      0        0
# 15996                 2.0  ...                      0        0
# 15997                 2.0  ...                      0        0
# 15998                 2.0  ...                      0        0
# 15999                 3.0  ...                      0        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 0                           1                  0                   0
# 1                           0                  0                   0
# 2                           1                  0                   0
# 4                           0                  0                   0
# 5                           0                  1                   0
# ...                       ...                ...                 ...
# 15994                       1                  0                   0
# 15996                       0                  0                   0
# 15997                       0                  0                   1
# 15998                       0                  0                   0
# 15999                       0                  0                   1
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 0                    0                     0         1        0       0
# 1                    0                     1         0        1       0
# 2                    0                     0         0        1       0
# 4                    0                     0         0        0       1
# 5                    0                     0         1        0       0
# ...                ...                   ...       ...      ...     ...
# 15994                0                     0         0        1       0
# 15996                1                     0         0        0       1
# 15997                0                     0         0        0       1
# 15998                0                     0         0        1       0
# 15999                0                     0         0        0       1
#
# [13554 rows x 47 columns]

# %%
norm_df = Normalize(df)

# %%
norm_df
# Out:
#        Target       Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 0           0 -0.242771      -0.727341          5                   0
# 1           0 -1.212807       0.390193          5                   0
# 2           0  0.484755      -0.463096          2                   0
# 4           0 -0.727789      -0.259408          3                   0
# 5           0 -0.646953       1.656365          2                   1
# ...       ...       ...            ...        ...                 ...
# 15994       0 -1.212807      -0.248398          2                   0
# 15996       0  1.373954      -0.094255          2                   0
# 15997       0 -1.051134      -0.688805          1                   0
# 15998       0 -0.808625      -0.914514          4                   1
# 15999       0  0.161410       1.243483          3                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 0                            1               1                2    -0.606832
# 1                            1               1                4    -0.297836
# 2                            1               3                4     2.019630
# 4                            1               2                4    -0.297836
# 5                            1               4                4     0.011159
# ...                        ...             ...              ...          ...
# 15994                        0               4                4     1.092644
# 15996                        0               2                3     0.474653
# 15997                        1               4                4    -0.606832
# 15998                        0               4                2    -0.452334
# 15999                        0               4                2    -1.070325
#
#        MicromanagedAtWork  ...  Laboratory Technician  Manager  \
# 0                     3.0  ...                      0        0
# 1                     4.0  ...                      0        0
# 2                     4.0  ...                      0        0
# 4                     5.0  ...                      0        0
# 5                     3.0  ...                      0        0
# ...                   ...  ...                    ...      ...
# 15994                 1.0  ...                      0        0
# 15996                 2.0  ...                      0        0
# 15997                 2.0  ...                      0        0
# 15998                 2.0  ...                      0        0
# 15999                 3.0  ...                      0        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 0                           1                  0                   0
# 1                           0                  0                   0
# 2                           1                  0                   0
# 4                           0                  0                   0
# 5                           0                  1                   0
# ...                       ...                ...                 ...
# 15994                       1                  0                   0
# 15996                       0                  0                   0
# 15997                       0                  0                   1
# 15998                       0                  0                   0
# 15999                       0                  0                   1
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 0                    0                     0         1        0       0
# 1                    0                     1         0        1       0
# 2                    0                     0         0        1       0
# 4                    0                     0         0        0       1
# 5                    0                     0         1        0       0
# ...                ...                   ...       ...      ...     ...
# 15994                0                     0         0        1       0
# 15996                1                     0         0        0       1
# 15997                0                     0         0        0       1
# 15998                0                     0         0        1       0
# 15999                0                     0         0        0       1
#
# [13554 rows x 47 columns]

# %%
norm_df['Target'].value_counts()
# Out:
# 0    11145
# 1     2409
# Name: Target, dtype: int64

# %%
norm_df.columns
# Out:
# Index(['Target', 'Age', 'AvgDailyHours', 'Education', 'HasFlexibleTimings',
#        'IsIndividualContributor', 'JobInvolvement', 'JobSatisfaction',
#        'LeavesTaken', 'MicromanagedAtWork', 'MonthlyIncome',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'RemoteWorkSatistfaction',
#        'SelfMotivationLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'WorkLoadLevel', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Human Resources',
#        'Research & Development', 'Sales', 'Human Resources', 'Life Sciences',
#        'Marketing', 'Medical', 'Other', 'Technical Degree', 'Female', 'Male',
#        'Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative',
#        'Divorced', 'Married', 'Single'],
#       dtype='object')

# %%
from sklearn.utils import resample
# Separate majority and minority classes
df_1 = norm_df[norm_df['Target']==0 ]
df_2 = norm_df[norm_df['Target']==1]

 
# Downsample majority class and upsample the minority class
df_11 = resample(df_1, replace=True,n_samples=5500,random_state=123) 
df_22 = resample(df_2, replace=True,n_samples=5500,random_state=123)

 
# Combine minority class with downsampled majority class
df_upsampled = pd.concat([df_11,df_22])
 
# Display new class counts
df_upsampled['Target'].value_counts()
# Out:
# 0    5500
# 1    5500
# Name: Target, dtype: int64

# %%
# shuffle the DataFrame rows 
data= df_upsampled.sample(frac = 1)

# %%
X = data[['Age', 'AvgDailyHours', 'Education', 'HasFlexibleTimings',
       'IsIndividualContributor', 'JobInvolvement', 'JobSatisfaction',
       'LeavesTaken', 'MicromanagedAtWork', 'MonthlyIncome',
       'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'RemoteWorkSatistfaction',
       'SelfMotivationLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'WorkLoadLevel', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Human Resources',
       'Research & Development', 'Sales', 'Human Resources', 'Life Sciences',
       'Marketing', 'Medical', 'Other', 'Technical Degree', 'Female', 'Male',
       'Healthcare Representative', 'Human Resources', 'Laboratory Technician',
       'Manager', 'Manufacturing Director', 'Research Director',
       'Research Scientist', 'Sales Executive', 'Sales Representative',
       'Divorced', 'Married', 'Single']]

y = data['Target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=40)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (8800, 52) (8800,)
# Test set: (2200, 52) (2200,)

# %%
x_train
# Out:
#             Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 9663   1.535627      -0.413551          3                   1
# 5810  -1.455316      -0.297944          2                   1
# 5361  -0.646953      -0.364005          3                   0
# 12088 -1.131970      -0.132791          5                   0
# 10975 -1.374479       0.390193          2                   0
# ...         ...            ...        ...                 ...
# 3144   1.050609       0.505800          5                   1
# 8097   1.697300       0.621407          3                   1
# 8909  -0.485280      -0.870473          3                   0
# 13000  0.727264      -0.270418          3                   0
# 2633  -0.566116      -0.116276          1                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 9663                         0               1                1    -0.143338
# 5810                         0               3                1    -0.606832
# 5361                         1               1                1    -0.606832
# 12088                        0               1                3     0.938146
# 10975                        1               1                2    -0.606832
# ...                        ...             ...              ...          ...
# 3144                         0               4                4     2.792119
# 8097                         0               1                2    -0.143338
# 8909                         1               1                4    -0.297836
# 13000                        0               1                3     2.637621
# 2633                         0               1                1    -0.761329
#
#        MicromanagedAtWork  MonthlyIncome  ...  Laboratory Technician  Manager  \
# 9663                  2.0      -0.006764  ...                      0        0
# 5810                  2.0      -0.336322  ...                      0        0
# 5361                  3.0      -0.092605  ...                      1        0
# 12088                 4.0      -0.215237  ...                      0        0
# 10975                 5.0      -0.301078  ...                      0        0
# ...                   ...            ...  ...                    ...      ...
# 3144                  2.0       0.164920  ...                      0        0
# 8097                  5.0       0.410181  ...                      0        1
# 8909                  5.0      -0.129394  ...                      0        0
# 13000                 1.0       0.299813  ...                      0        0
# 2633                  5.0      -0.227499  ...                      0        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 9663                        0                  0                   1
# 5810                        0                  0                   0
# 5361                        0                  0                   0
# 12088                       0                  0                   0
# 10975                       0                  0                   0
# ...                       ...                ...                 ...
# 3144                        0                  0                   0
# 8097                        0                  0                   0
# 8909                        0                  0                   0
# 13000                       0                  0                   0
# 2633                        0                  1                   0
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 9663                 0                     0         0        0       1
# 5810                 0                     0         0        1       0
# 5361                 0                     0         0        0       1
# 12088                0                     0         1        0       0
# 10975                0                     1         1        0       0
# ...                ...                   ...       ...      ...     ...
# 3144                 0                     0         0        0       1
# 8097                 0                     0         1        0       0
# 8909                 1                     0         0        1       0
# 13000                0                     1         0        0       1
# 2633                 0                     0         0        1       0
#
# [8800 rows x 52 columns]

# %%
x_test
# Out:
#             Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 1570  -0.727789       1.667375          2                   0
# 1263  -0.970298       1.683890          5                   1
# 15709  0.969773      -0.650270          5                   0
# 6123  -0.242771      -0.198852          4                   0
# 4040  -0.970298       5.647558          4                   1
# ...         ...            ...        ...                 ...
# 2735  -1.212807      -0.248398          1                   0
# 13345 -0.808625       1.177422          1                   0
# 14863  1.454791      -0.870473          5                   0
# 15286 -1.697824       1.617829          3                   0
# 483    0.080574       0.885652          1                   1
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 1570                         0               1                2    -0.452334
# 1263                         0               2                3    -0.761329
# 15709                        1               1                1     2.328626
# 6123                         0               2                1     0.320155
# 4040                         0               1                2    -0.143338
# ...                        ...             ...              ...          ...
# 2735                         1               3                1    -0.452334
# 13345                        0               4                1     0.011159
# 14863                        0               4                1     0.474653
# 15286                        1               2                1    -0.452334
# 483                          1               4                1    -0.606832
#
#        MicromanagedAtWork  MonthlyIncome  ...  Laboratory Technician  Manager  \
# 1570                  2.0      -0.166183  ...                      0        0
# 1263                  1.0      -0.178447  ...                      1        0
# 15709                 2.0      -0.068080  ...                      1        0
# 6123                  4.0       0.005499  ...                      0        0
# 4040                  5.0      -0.227499  ...                      0        0
# ...                   ...            ...  ...                    ...      ...
# 2735                  4.0      -0.313340  ...                      0        0
# 13345                 3.0      -0.227499  ...                      0        0
# 14863                 2.0       0.140393  ...                      0        0
# 15286                 5.0      -0.313340  ...                      0        0
# 483                   4.0       0.079078  ...                      1        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 1570                        0                  0                   0
# 1263                        0                  0                   0
# 15709                       0                  0                   0
# 6123                        0                  0                   0
# 4040                        0                  0                   0
# ...                       ...                ...                 ...
# 2735                        0                  0                   0
# 13345                       0                  0                   0
# 14863                       0                  1                   0
# 15286                       0                  0                   0
# 483                         0                  0                   0
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 1570                 0                     0         1        0       0
# 1263                 0                     0         0        0       1
# 15709                0                     0         0        1       0
# 6123                 0                     1         0        0       1
# 4040                 0                     0         1        0       0
# ...                ...                   ...       ...      ...     ...
# 2735                 0                     0         1        0       0
# 13345                0                     0         0        0       1
# 14863                0                     0         0        1       0
# 15286                0                     1         0        1       0
# 483                  0                     0         1        0       0
#
# [2200 rows x 52 columns]

# %%
x_test.to_csv('stress_test.csv',index=False)

# %%
y_train
# Out:
# 9663     1
# 5810     0
# 5361     1
# 12088    1
# 10975    1
#         ..
# 3144     0
# 8097     1
# 8909     0
# 13000    0
# 2633     0
# Name: Target, Length: 8800, dtype: int64

# %%
y_test
# Out:
# 1570     1
# 1263     0
# 15709    0
# 6123     1
# 4040     1
#         ..
# 2735     0
# 13345    1
# 14863    1
# 15286    1
# 483      1
# Name: Target, Length: 2200, dtype: int64

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import GridSearchCV

dept = [1, 5, 10, 50, 100, 500, 1000]
n_estimators =  [20, 40, 60, 80, 100, 120]


param_grid={'n_estimators':n_estimators , 'max_depth':dept}
clf = RandomForestClassifier()
model = GridSearchCV(clf,param_grid,scoring='accuracy',n_jobs=-1,cv=3)
model.fit(x_train,y_train)
print("optimal n_estimators",model.best_estimator_.n_estimators)
print("optimal max_depth",model.best_estimator_.max_depth)
optimal_n_estimators = model.best_estimator_.n_estimators
optimal_max_depth = model.best_estimator_.max_depth
# Out:
# optimal n_estimators 120
# optimal max_depth 1000

# %%
#Testing AUC on Test data
rf = RandomForestClassifier(criterion='gini',max_depth = optimal_max_depth,n_estimators =700)

rf.fit(x_train,y_train)

#predict on test data and train data
 
y_predtest = rf.predict(x_test)
y_predtrain = rf.predict(x_train)

print('*'*35)

#accuracy on training and testing data

print('the accuracy on testing data',accuracy_score(y_test,y_predtest))
print('the accuracy on training data',accuracy_score(y_train,y_predtrain))
train1 = accuracy_score(y_train,y_predtrain)
test1 = accuracy_score(y_test,y_predtest)

print('*'*35)


# Code for drawing seaborn heatmaps
class_names = ['stress', 'composure']
cm = pd.DataFrame(confusion_matrix(y_test, y_predtest.round()), index=class_names, columns=class_names )
fig = m.figure( )
heatmap = s.heatmap(cm, annot=True, fmt="d")
# Out:
# ***********************************
# the accuracy on testing data 0.9604545454545454
# the accuracy on training data 1.0
# ***********************************

# %%
new = ['Random Forest','RandomForestClassifier',train1, test1]
all_model_result.loc[1] = new

# %% [markdown]
# ## K - Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
ks = 10
error_rate = []

# Will take some time
for i in range(1,ks):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    yhatknn = knn.predict(x_test)
    error_rate.append(np.mean(yhatknn != y_test))
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
m.figure(figsize=(10,6))
m.plot(range(1,ks),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
m.title('Error Rate vs. K Value')
m.xlabel('K')
m.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
#Testing AUC on Test data
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
#predict on test data and train data
 
y_predtest = knn.predict(x_test)
y_predtrain = knn.predict(x_train)

print('*'*35)

#accuracy on training and testing data

print('the accuracy on testing data',accuracy_score(y_test,y_predtest))
print('the accuracy on training data',accuracy_score(y_train,y_predtrain))
train2 = accuracy_score(y_train,y_predtrain)
test2 = accuracy_score(y_test,y_predtest)

print('*'*35)


# Code for drawing seaborn heatmaps
class_names = ['stress', 'composure']
cm = pd.DataFrame(confusion_matrix(y_test, y_predtest.round()), index=class_names, columns=class_names )
fig = m.figure( )
heatmap = s.heatmap(cm, annot=True, fmt="d")
# Out:
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\ST-0006\anaconda3\envs\keras_env\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# ***********************************
# the accuracy on testing data 0.7654545454545455
# the accuracy on training data 0.8486363636363636
# ***********************************

# %%
new = ['KNN','K - Nearest NeighboursClassifier',train2, test2]
all_model_result.loc[2] = new

# %%
all_model_result
# Out:
#        Algorithm                        Classifier  Train-Accuracy  \
# 0  Decison tree           DECISION-TREE-Classifier        0.987841
# 1  Random Forest            RandomForestClassifier        1.000000
# 2            KNN  K - Nearest NeighboursClassifier        0.848636
#
#    Test-Accuracy
# 0       0.880000
# 1       0.958636
# 2       0.765455
