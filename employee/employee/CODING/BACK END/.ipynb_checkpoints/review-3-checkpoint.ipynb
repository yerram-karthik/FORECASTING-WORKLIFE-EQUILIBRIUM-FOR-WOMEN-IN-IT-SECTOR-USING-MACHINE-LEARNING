# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as m
import seaborn as s
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import  confusion_matrix, classification_report, accuracy_score

# %%
s.set_style("darkgrid")
m.rcParams['font.size'] = 14
m.rcParams['figure.figsize'] = (9, 5)
m.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv(r'C:\Users\yerra\Downloads\employee\employee\DATASET\train.csv',delimiter = ';')
df
# Out:
#        EmployeeID  Target   Age  AvgDailyHours              Department  \
# 0          100001       0  36.0           6.45                   Sales
# 1          100002       0  24.0           8.48                   Sales
# 2          100003       0  45.0           6.93  Research & Development
# 3          100004       1  29.0           7.10                   Sales
# 4          100005       0  30.0           7.30         Human Resources
# ...           ...     ...   ...            ...                     ...
# 15995      115996       0  19.0           6.81                   Sales
# 15996      115997       0  56.0           7.60                   Sales
# 15997      115998       0  26.0           6.52         Human Resources
# 15998      115999       0  29.0           6.11  Research & Development
# 15999      116000       0  41.0          10.03         Human Resources
#
#        Education    EducationField  Gender HasFlexibleTimings  \
# 0              5  Technical Degree    Male                 No
# 1              5  Technical Degree    Male                 No
# 2              2  Technical Degree  Female                 No
# 3              4           Medical    Male                 No
# 4              3     Life Sciences  Female                 No
# ...          ...               ...     ...                ...
# 15995          2             Other    Male                Yes
# 15996          2  Technical Degree  Female                 No
# 15997          1             Other  Female                 No
# 15998          4   Human Resources  Female                Yes
# 15999          3   Human Resources    Male                 No
#
#       IsIndividualContributor  ...  RelationshipSatisfaction  \
# 0                         Yes  ...                         1
# 1                         Yes  ...                         1
# 2                         Yes  ...                         4
# 3                          No  ...                         4
# 4                         Yes  ...                         1
# ...                       ...  ...                       ...
# 15995                     Yes  ...                         3
# 15996                      No  ...                         2
# 15997                     Yes  ...                         3
# 15998                      No  ...                         1
# 15999                      No  ...                         2
#
#       RemoteWorkSatistfaction  SelfMotivationLevel  TotalWorkingYears  \
# 0                      Medium                    3                8.0
# 1                   Very High                    2                1.0
# 2                        High                    1               17.0
# 3                      Medium                    2                2.0
# 4                   Very High                    4                9.0
# ...                       ...                  ...                ...
# 15995                    High                    2                0.0
# 15996                     Low                    2                7.0
# 15997                    High                    4                5.0
# 15998                    High                    2                6.0
# 15999                  Medium                    3               18.0
#
#       TrainingTimesLastYear  WorkLifeBalance  WorkLoadLevel  YearsAtCompany  \
# 0                         2                2            Low             8.0
# 1                         5                2           High             0.0
# 2                         6                4            Low            17.0
# 3                         0                2            NaN             1.0
# 4                         6                1         Medium             3.0
# ...                     ...              ...            ...             ...
# 15995                     3                1            NaN             0.0
# 15996                     2                1         Medium             6.0
# 15997                     3                4           High             1.0
# 15998                     3                1           High             1.0
# 15999                     3                3           High             0.0
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# 0                          1.0                   8.0
# 1                          0.0                   0.0
# 2                          4.0                  10.0
# 3                          1.0                   1.0
# 4                          3.0                   0.0
# ...                        ...                   ...
# 15995                      0.0                   0.0
# 15996                      2.0                   2.0
# 15997                      1.0                   1.0
# 15998                      1.0                   1.0
# 15999                      0.0                   0.0
#
# [16000 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                16000 non-null  int64
#  1   Target                    16000 non-null  int64
#  2   Age                       15393 non-null  float64
#  3   AvgDailyHours             16000 non-null  float64
#  4   Department                16000 non-null  object
#  5   Education                 16000 non-null  int64
#  6   EducationField            16000 non-null  object
#  7   Gender                    15652 non-null  object
#  8   HasFlexibleTimings        15831 non-null  object
#  9   IsIndividualContributor   15675 non-null  object
#  10  JobInvolvement            16000 non-null  int64
#  11  JobRole                   15630 non-null  object
#  12  JobSatisfaction           16000 non-null  int64
#  13  LeavesTaken               15951 non-null  float64
#  14  MaritalStatus             15766 non-null  object
#  15  MicromanagedAtWork        15862 non-null  float64
#  16  MonthlyIncome             16000 non-null  int64
#  17  NumCompaniesWorked        16000 non-null  int64
#  18  PercentSalaryHike         16000 non-null  int64
#  19  PerformanceRating         16000 non-null  int64
#  20  RelationshipSatisfaction  16000 non-null  int64
#  21  RemoteWorkSatistfaction   16000 non-null  object
#  22  SelfMotivationLevel       16000 non-null  int64
#  23  TotalWorkingYears         15667 non-null  float64
#  24  TrainingTimesLastYear     16000 non-null  int64
#  25  WorkLifeBalance           16000 non-null  int64
#  26  WorkLoadLevel             15587 non-null  object
#  27  YearsAtCompany            15667 non-null  float64
#  28  YearsSinceLastPromotion   15667 non-null  float64
#  29  YearsWithCurrManager      15667 non-null  float64
# dtypes: float64(8), int64(13), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum(axis=0)
# Out:
# EmployeeID                    0
# Target                        0
# Age                         607
# AvgDailyHours                 0
# Department                    0
# Education                     0
# EducationField                0
# Gender                      348
# HasFlexibleTimings          169
# IsIndividualContributor     325
# JobInvolvement                0
# JobRole                     370
# JobSatisfaction               0
# LeavesTaken                  49
# MaritalStatus               234
# MicromanagedAtWork          138
# MonthlyIncome                 0
# NumCompaniesWorked            0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# RemoteWorkSatistfaction       0
# SelfMotivationLevel           0
# TotalWorkingYears           333
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# WorkLoadLevel               413
# YearsAtCompany              333
# YearsSinceLastPromotion     333
# YearsWithCurrManager        333
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#        EmployeeID  Target   Age  AvgDailyHours              Department  \
# 0          100001       0  36.0           6.45                   Sales
# 1          100002       0  24.0           8.48                   Sales
# 2          100003       0  45.0           6.93  Research & Development
# 4          100005       0  30.0           7.30         Human Resources
# 5          100006       0  31.0          10.78                   Sales
# ...           ...     ...   ...            ...                     ...
# 15994      115995       0  24.0           7.32  Research & Development
# 15996      115997       0  56.0           7.60                   Sales
# 15997      115998       0  26.0           6.52         Human Resources
# 15998      115999       0  29.0           6.11  Research & Development
# 15999      116000       0  41.0          10.03         Human Resources
#
#        Education    EducationField  Gender HasFlexibleTimings  \
# 0              5  Technical Degree    Male                 No
# 1              5  Technical Degree    Male                 No
# 2              2  Technical Degree  Female                 No
# 4              3     Life Sciences  Female                 No
# 5              2           Medical    Male                Yes
# ...          ...               ...     ...                ...
# 15994          2             Other  Female                 No
# 15996          2  Technical Degree  Female                 No
# 15997          1             Other  Female                 No
# 15998          4   Human Resources  Female                Yes
# 15999          3   Human Resources    Male                 No
#
#       IsIndividualContributor  ...  RelationshipSatisfaction  \
# 0                         Yes  ...                         1
# 1                         Yes  ...                         1
# 2                         Yes  ...                         4
# 4                         Yes  ...                         1
# 5                         Yes  ...                         2
# ...                       ...  ...                       ...
# 15994                      No  ...                         4
# 15996                      No  ...                         2
# 15997                     Yes  ...                         3
# 15998                      No  ...                         1
# 15999                      No  ...                         2
#
#       RemoteWorkSatistfaction  SelfMotivationLevel  TotalWorkingYears  \
# 0                      Medium                    3                8.0
# 1                   Very High                    2                1.0
# 2                        High                    1               17.0
# 4                   Very High                    4                9.0
# 5                        High                    1                9.0
# ...                       ...                  ...                ...
# 15994               Very High                    2                3.0
# 15996                     Low                    2                7.0
# 15997                    High                    4                5.0
# 15998                    High                    2                6.0
# 15999                  Medium                    3               18.0
#
#       TrainingTimesLastYear  WorkLifeBalance  WorkLoadLevel  YearsAtCompany  \
# 0                         2                2            Low             8.0
# 1                         5                2           High             0.0
# 2                         6                4            Low            17.0
# 4                         6                1         Medium             3.0
# 5                         0                4           High             2.0
# ...                     ...              ...            ...             ...
# 15994                     5                3            Low             3.0
# 15996                     2                1         Medium             6.0
# 15997                     3                4           High             1.0
# 15998                     3                1           High             1.0
# 15999                     3                3           High             0.0
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# 0                          1.0                   8.0
# 1                          0.0                   0.0
# 2                          4.0                  10.0
# 4                          3.0                   0.0
# 5                          2.0                   2.0
# ...                        ...                   ...
# 15994                      3.0                   1.0
# 15996                      2.0                   2.0
# 15997                      1.0                   1.0
# 15998                      1.0                   1.0
# 15999                      0.0                   0.0
#
# [13554 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13554 entries, 0 to 15999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                13554 non-null  int64
#  1   Target                    13554 non-null  int64
#  2   Age                       13554 non-null  float64
#  3   AvgDailyHours             13554 non-null  float64
#  4   Department                13554 non-null  object
#  5   Education                 13554 non-null  int64
#  6   EducationField            13554 non-null  object
#  7   Gender                    13554 non-null  object
#  8   HasFlexibleTimings        13554 non-null  object
#  9   IsIndividualContributor   13554 non-null  object
#  10  JobInvolvement            13554 non-null  int64
#  11  JobRole                   13554 non-null  object
#  12  JobSatisfaction           13554 non-null  int64
#  13  LeavesTaken               13554 non-null  float64
#  14  MaritalStatus             13554 non-null  object
#  15  MicromanagedAtWork        13554 non-null  float64
#  16  MonthlyIncome             13554 non-null  int64
#  17  NumCompaniesWorked        13554 non-null  int64
#  18  PercentSalaryHike         13554 non-null  int64
#  19  PerformanceRating         13554 non-null  int64
#  20  RelationshipSatisfaction  13554 non-null  int64
#  21  RemoteWorkSatistfaction   13554 non-null  object
#  22  SelfMotivationLevel       13554 non-null  int64
#  23  TotalWorkingYears         13554 non-null  float64
#  24  TrainingTimesLastYear     13554 non-null  int64
#  25  WorkLifeBalance           13554 non-null  int64
#  26  WorkLoadLevel             13554 non-null  object
#  27  YearsAtCompany            13554 non-null  float64
#  28  YearsSinceLastPromotion   13554 non-null  float64
#  29  YearsWithCurrManager      13554 non-null  float64
# dtypes: float64(8), int64(13), object(9)
# memory usage: 3.2+ MB

# %%
df.reset_index(inplace = True)
df
# Out:
#        index  EmployeeID  Target   Age  AvgDailyHours              Department  \
# 0          0      100001       0  36.0           6.45                   Sales
# 1          1      100002       0  24.0           8.48                   Sales
# 2          2      100003       0  45.0           6.93  Research & Development
# 3          4      100005       0  30.0           7.30         Human Resources
# 4          5      100006       0  31.0          10.78                   Sales
# ...      ...         ...     ...   ...            ...                     ...
# 13549  15994      115995       0  24.0           7.32  Research & Development
# 13550  15996      115997       0  56.0           7.60                   Sales
# 13551  15997      115998       0  26.0           6.52         Human Resources
# 13552  15998      115999       0  29.0           6.11  Research & Development
# 13553  15999      116000       0  41.0          10.03         Human Resources
#
#        Education    EducationField  Gender HasFlexibleTimings  ...  \
# 0              5  Technical Degree    Male                 No  ...
# 1              5  Technical Degree    Male                 No  ...
# 2              2  Technical Degree  Female                 No  ...
# 3              3     Life Sciences  Female                 No  ...
# 4              2           Medical    Male                Yes  ...
# ...          ...               ...     ...                ...  ...
# 13549          2             Other  Female                 No  ...
# 13550          2  Technical Degree  Female                 No  ...
# 13551          1             Other  Female                 No  ...
# 13552          4   Human Resources  Female                Yes  ...
# 13553          3   Human Resources    Male                 No  ...
#
#       RelationshipSatisfaction  RemoteWorkSatistfaction SelfMotivationLevel  \
# 0                            1                   Medium                   3
# 1                            1                Very High                   2
# 2                            4                     High                   1
# 3                            1                Very High                   4
# 4                            2                     High                   1
# ...                        ...                      ...                 ...
# 13549                        4                Very High                   2
# 13550                        2                      Low                   2
# 13551                        3                     High                   4
# 13552                        1                     High                   2
# 13553                        2                   Medium                   3
#
#        TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                    8.0                      2               2
# 1                    1.0                      5               2
# 2                   17.0                      6               4
# 3                    9.0                      6               1
# 4                    9.0                      0               4
# ...                  ...                    ...             ...
# 13549                3.0                      5               3
# 13550                7.0                      2               1
# 13551                5.0                      3               4
# 13552                6.0                      3               1
# 13553               18.0                      3               3
#
#        WorkLoadLevel  YearsAtCompany  YearsSinceLastPromotion  \
# 0                Low             8.0                      1.0
# 1               High             0.0                      0.0
# 2                Low            17.0                      4.0
# 3             Medium             3.0                      3.0
# 4               High             2.0                      2.0
# ...              ...             ...                      ...
# 13549            Low             3.0                      3.0
# 13550         Medium             6.0                      2.0
# 13551           High             1.0                      1.0
# 13552           High             1.0                      1.0
# 13553           High             0.0                      0.0
#
#        YearsWithCurrManager
# 0                       8.0
# 1                       0.0
# 2                      10.0
# 3                       0.0
# 4                       2.0
# ...                     ...
# 13549                   1.0
# 13550                   2.0
# 13551                   1.0
# 13552                   1.0
# 13553                   0.0
#
# [13554 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13554 entries, 0 to 13553
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     13554 non-null  int64
#  1   EmployeeID                13554 non-null  int64
#  2   Target                    13554 non-null  int64
#  3   Age                       13554 non-null  float64
#  4   AvgDailyHours             13554 non-null  float64
#  5   Department                13554 non-null  object
#  6   Education                 13554 non-null  int64
#  7   EducationField            13554 non-null  object
#  8   Gender                    13554 non-null  object
#  9   HasFlexibleTimings        13554 non-null  object
#  10  IsIndividualContributor   13554 non-null  object
#  11  JobInvolvement            13554 non-null  int64
#  12  JobRole                   13554 non-null  object
#  13  JobSatisfaction           13554 non-null  int64
#  14  LeavesTaken               13554 non-null  float64
#  15  MaritalStatus             13554 non-null  object
#  16  MicromanagedAtWork        13554 non-null  float64
#  17  MonthlyIncome             13554 non-null  int64
#  18  NumCompaniesWorked        13554 non-null  int64
#  19  PercentSalaryHike         13554 non-null  int64
#  20  PerformanceRating         13554 non-null  int64
#  21  RelationshipSatisfaction  13554 non-null  int64
#  22  RemoteWorkSatistfaction   13554 non-null  object
#  23  SelfMotivationLevel       13554 non-null  int64
#  24  TotalWorkingYears         13554 non-null  float64
#  25  TrainingTimesLastYear     13554 non-null  int64
#  26  WorkLifeBalance           13554 non-null  int64
#  27  WorkLoadLevel             13554 non-null  object
#  28  YearsAtCompany            13554 non-null  float64
#  29  YearsSinceLastPromotion   13554 non-null  float64
#  30  YearsWithCurrManager      13554 non-null  float64
# dtypes: float64(8), int64(14), object(9)
# memory usage: 3.2+ MB

# %%
df = df.drop('index', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13554 entries, 0 to 13553
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                13554 non-null  int64
#  1   Target                    13554 non-null  int64
#  2   Age                       13554 non-null  float64
#  3   AvgDailyHours             13554 non-null  float64
#  4   Department                13554 non-null  object
#  5   Education                 13554 non-null  int64
#  6   EducationField            13554 non-null  object
#  7   Gender                    13554 non-null  object
#  8   HasFlexibleTimings        13554 non-null  object
#  9   IsIndividualContributor   13554 non-null  object
#  10  JobInvolvement            13554 non-null  int64
#  11  JobRole                   13554 non-null  object
#  12  JobSatisfaction           13554 non-null  int64
#  13  LeavesTaken               13554 non-null  float64
#  14  MaritalStatus             13554 non-null  object
#  15  MicromanagedAtWork        13554 non-null  float64
#  16  MonthlyIncome             13554 non-null  int64
#  17  NumCompaniesWorked        13554 non-null  int64
#  18  PercentSalaryHike         13554 non-null  int64
#  19  PerformanceRating         13554 non-null  int64
#  20  RelationshipSatisfaction  13554 non-null  int64
#  21  RemoteWorkSatistfaction   13554 non-null  object
#  22  SelfMotivationLevel       13554 non-null  int64
#  23  TotalWorkingYears         13554 non-null  float64
#  24  TrainingTimesLastYear     13554 non-null  int64
#  25  WorkLifeBalance           13554 non-null  int64
#  26  WorkLoadLevel             13554 non-null  object
#  27  YearsAtCompany            13554 non-null  float64
#  28  YearsSinceLastPromotion   13554 non-null  float64
#  29  YearsWithCurrManager      13554 non-null  float64
# dtypes: float64(8), int64(13), object(9)
# memory usage: 3.1+ MB

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Target', 'Age', 'AvgDailyHours', 'Department',
#        'Education', 'EducationField', 'Gender', 'HasFlexibleTimings',
#        'IsIndividualContributor', 'JobInvolvement', 'JobRole',
#        'JobSatisfaction', 'LeavesTaken', 'MaritalStatus', 'MicromanagedAtWork',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction',
#        'RemoteWorkSatistfaction', 'SelfMotivationLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'WorkLoadLevel',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df
# Out:
#        EmployeeID  Target   Age  AvgDailyHours              Department  \
# 0          100001       0  36.0           6.45                   Sales
# 1          100002       0  24.0           8.48                   Sales
# 2          100003       0  45.0           6.93  Research & Development
# 3          100005       0  30.0           7.30         Human Resources
# 4          100006       0  31.0          10.78                   Sales
# ...           ...     ...   ...            ...                     ...
# 13549      115995       0  24.0           7.32  Research & Development
# 13550      115997       0  56.0           7.60                   Sales
# 13551      115998       0  26.0           6.52         Human Resources
# 13552      115999       0  29.0           6.11  Research & Development
# 13553      116000       0  41.0          10.03         Human Resources
#
#        Education    EducationField  Gender HasFlexibleTimings  \
# 0              5  Technical Degree    Male                 No
# 1              5  Technical Degree    Male                 No
# 2              2  Technical Degree  Female                 No
# 3              3     Life Sciences  Female                 No
# 4              2           Medical    Male                Yes
# ...          ...               ...     ...                ...
# 13549          2             Other  Female                 No
# 13550          2  Technical Degree  Female                 No
# 13551          1             Other  Female                 No
# 13552          4   Human Resources  Female                Yes
# 13553          3   Human Resources    Male                 No
#
#       IsIndividualContributor  ...  RelationshipSatisfaction  \
# 0                         Yes  ...                         1
# 1                         Yes  ...                         1
# 2                         Yes  ...                         4
# 3                         Yes  ...                         1
# 4                         Yes  ...                         2
# ...                       ...  ...                       ...
# 13549                      No  ...                         4
# 13550                      No  ...                         2
# 13551                     Yes  ...                         3
# 13552                      No  ...                         1
# 13553                      No  ...                         2
#
#       RemoteWorkSatistfaction  SelfMotivationLevel  TotalWorkingYears  \
# 0                      Medium                    3                8.0
# 1                   Very High                    2                1.0
# 2                        High                    1               17.0
# 3                   Very High                    4                9.0
# 4                        High                    1                9.0
# ...                       ...                  ...                ...
# 13549               Very High                    2                3.0
# 13550                     Low                    2                7.0
# 13551                    High                    4                5.0
# 13552                    High                    2                6.0
# 13553                  Medium                    3               18.0
#
#       TrainingTimesLastYear  WorkLifeBalance  WorkLoadLevel  YearsAtCompany  \
# 0                         2                2            Low             8.0
# 1                         5                2           High             0.0
# 2                         6                4            Low            17.0
# 3                         6                1         Medium             3.0
# 4                         0                4           High             2.0
# ...                     ...              ...            ...             ...
# 13549                     5                3            Low             3.0
# 13550                     2                1         Medium             6.0
# 13551                     3                4           High             1.0
# 13552                     3                1           High             1.0
# 13553                     3                3           High             0.0
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# 0                          1.0                   8.0
# 1                          0.0                   0.0
# 2                          4.0                  10.0
# 3                          3.0                   0.0
# 4                          2.0                   2.0
# ...                        ...                   ...
# 13549                      3.0                   1.0
# 13550                      2.0                   2.0
# 13551                      1.0                   1.0
# 13552                      1.0                   1.0
# 13553                      0.0                   0.0
#
# [13554 rows x 30 columns]

# %%
m.figure(figsize=(8,5))
m.title('Number of Employees under Stress')
s.countplot(x = df.Target) #0-not in stress and 1-in stress
# Out:
# <Axes: title={'center': 'Number of Employees under Stress'}, xlabel='Target', ylabel='count'>

# %%
m.figure(figsize=(10,8))
m.title('Age vs Education')

s.scatterplot(y=df["Education"],x=df["Age"],hue=df.Target)
# Out:
# <Axes: title={'center': 'Age vs Education'}, xlabel='Age', ylabel='Education'>

# %%
m.figure(figsize=(10,8))
m.title('Job Satisfaction vs Education Field')
s.boxplot(y=df["EducationField"],x=df["JobSatisfaction"], hue=df.Target)
# Out:
# <Axes: title={'center': 'Job Satisfaction vs Education Field'}, xlabel='JobSatisfaction', ylabel='EducationField'>

# %%
m.figure(figsize=(10,8))
m.title('Average Daily Hours vs Has Flexible Timings')
s.boxplot(y=df["HasFlexibleTimings"],x=df["AvgDailyHours"], hue=df.Target)
# Out:
# <Axes: title={'center': 'Average Daily Hours vs Has Flexible Timings'}, xlabel='AvgDailyHours', ylabel='HasFlexibleTimings'>

# %%
s.distplot(df['JobSatisfaction'])
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='Density'>

# %%
s.distplot(df['Education'])
# Out:
# <Axes: xlabel='Education', ylabel='Density'>

# %%
s.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
s.distplot(df['YearsAtCompany'])
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='Density'>

# %%
m.figure(figsize=(10,8))
m.title('Job Involvement vs IsIndividualContributor')
s.boxplot(y=df["IsIndividualContributor"], x=df["JobInvolvement"], hue=df.Target)
# Out:
# <Axes: title={'center': 'Job Involvement vs IsIndividualContributor'}, xlabel='JobInvolvement', ylabel='IsIndividualContributor'>

# %%
s.distplot(df['YearsSinceLastPromotion'])
# Out:
# <Axes: xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
s.distplot(df['YearsWithCurrManager'])
# Out:
# <Axes: xlabel='YearsWithCurrManager', ylabel='Density'>

# %%
def Data_Processor(temp_frame):
    
    from sklearn.preprocessing import LabelEncoder
    label_encoder = LabelEncoder()
    temp = pd.DataFrame()
    temp_frame['HasFlexibleTimings']= label_encoder.fit_transform(temp_frame['HasFlexibleTimings']) 
    temp_frame['IsIndividualContributor']= label_encoder.fit_transform(temp_frame['IsIndividualContributor']) 
    temp_frame['RemoteWorkSatistfaction']= label_encoder.fit_transform(temp_frame['RemoteWorkSatistfaction']) 
    temp_frame['WorkLoadLevel']= label_encoder.fit_transform(temp_frame['WorkLoadLevel']) 
    temp = pd.concat([pd.get_dummies(temp_frame[col]) for col in ['Department','EducationField', 'Gender', 'JobRole', 'MaritalStatus']], axis=1)
    temp.groupby(level=0, axis=1).sum()
    temp_frame = pd.concat([temp_frame, temp], axis=1)
    temp_frame.drop(['Department','EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'EmployeeID'], axis=1, inplace=True)

    return temp_frame;

# %%
def Normalize(df): #main aim is to have zero mean and unit variance for meaningful comparison
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    frame = pd.DataFrame();
    frame = df
    frame.loc[:, ['Age', 'AvgDailyHours','LeavesTaken', 'MonthlyIncome', 
           'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany', 'YearsWithCurrManager']] = scaler.fit_transform(frame.loc[:, ['Age', 'AvgDailyHours','LeavesTaken', 'MonthlyIncome', 
           'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany', 'YearsWithCurrManager']]);
    return frame;

# %%
df = Data_Processor(df)
df
# Out:
#        Target   Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 0           0  36.0           6.45          5                   0
# 1           0  24.0           8.48          5                   0
# 2           0  45.0           6.93          2                   0
# 3           0  30.0           7.30          3                   0
# 4           0  31.0          10.78          2                   1
# ...       ...   ...            ...        ...                 ...
# 13549       0  24.0           7.32          2                   0
# 13550       0  56.0           7.60          2                   0
# 13551       0  26.0           6.52          1                   0
# 13552       0  29.0           6.11          4                   1
# 13553       0  41.0          10.03          3                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 0                            1               1                2          7.0
# 1                            1               1                4          9.0
# 2                            1               3                4         24.0
# 3                            1               2                4          9.0
# 4                            1               4                4         11.0
# ...                        ...             ...              ...          ...
# 13549                        0               4                4         18.0
# 13550                        0               2                3         14.0
# 13551                        1               4                4          7.0
# 13552                        0               4                2          8.0
# 13553                        0               4                2          4.0
#
#        MicromanagedAtWork  ...  Laboratory Technician  Manager  \
# 0                     3.0  ...                      0        0
# 1                     4.0  ...                      0        0
# 2                     4.0  ...                      0        0
# 3                     5.0  ...                      0        0
# 4                     3.0  ...                      0        0
# ...                   ...  ...                    ...      ...
# 13549                 1.0  ...                      0        0
# 13550                 2.0  ...                      0        0
# 13551                 2.0  ...                      0        0
# 13552                 2.0  ...                      0        0
# 13553                 3.0  ...                      0        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 0                           1                  0                   0
# 1                           0                  0                   0
# 2                           1                  0                   0
# 3                           0                  0                   0
# 4                           0                  1                   0
# ...                       ...                ...                 ...
# 13549                       1                  0                   0
# 13550                       0                  0                   0
# 13551                       0                  0                   1
# 13552                       0                  0                   0
# 13553                       0                  0                   1
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 0                    0                     0         1        0       0
# 1                    0                     1         0        1       0
# 2                    0                     0         0        1       0
# 3                    0                     0         0        0       1
# 4                    0                     0         1        0       0
# ...                ...                   ...       ...      ...     ...
# 13549                0                     0         0        1       0
# 13550                1                     0         0        0       1
# 13551                0                     0         0        0       1
# 13552                0                     0         0        1       0
# 13553                0                     0         0        0       1
#
# [13554 rows x 47 columns]

# %%
df['Target'].value_counts()
# Out:
# 0    11145
# 1     2409
# Name: Target, dtype: int64

# %%
df.columns
# Out:
# Index(['Target', 'Age', 'AvgDailyHours', 'Education', 'HasFlexibleTimings',
#        'IsIndividualContributor', 'JobInvolvement', 'JobSatisfaction',
#        'LeavesTaken', 'MicromanagedAtWork', 'MonthlyIncome',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'RemoteWorkSatistfaction',
#        'SelfMotivationLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'WorkLoadLevel', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Human Resources',
#        'Research & Development', 'Sales', 'Human Resources', 'Life Sciences',
#        'Marketing', 'Medical', 'Other', 'Technical Degree', 'Female', 'Male',
#        'Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative',
#        'Divorced', 'Married', 'Single'],
#       dtype='object')

# %%
from sklearn.utils import resample
# Separate majority and minority classes
df_1 = df[df['Target']==0 ]
df_2 = df[df['Target']==1]

 
# Downsample majority class and upsample the minority class
df_11 = resample(df_1, replace=True,n_samples=5500,random_state=123) 
df_22 = resample(df_2, replace=True,n_samples=5500,random_state=123)

 
# Combine minority class with downsampled majority class
df_upsampled = pd.concat([df_11,df_22])
 
# Display new class counts
df_upsampled['Target'].value_counts()
# Out:
# 0    5500
# 1    5500
# Name: Target, dtype: int64

# %%
df_upsampled
# Out:
#        Target   Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 4391        0  58.0           6.30          5                   1
# 1644        0  33.0           7.59          4                   0
# 6370        0  36.0           7.18          3                   1
# 9451        0  36.0           7.81          1                   1
# 11904       0  19.0           7.42          5                   1
# ...       ...   ...            ...        ...                 ...
# 1167        1  18.0           7.77          5                   1
# 11936       1  47.0           7.18          4                   0
# 2846        1  44.0           9.29          1                   0
# 11158       1  60.0           6.28          3                   0
# 1885        1  19.0           8.80          5                   1
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 4391                         0               1                2         25.0
# 1644                         0               2                4          5.0
# 6370                         1               4                3         10.0
# 9451                         0               4                4          6.0
# 11904                        1               4                3          6.0
# ...                        ...             ...              ...          ...
# 1167                         1               4                2          8.0
# 11936                        0               3                2         16.0
# 2846                         1               3                1         18.0
# 11158                        1               1                1         29.0
# 1885                         0               3                1         10.0
#
#        MicromanagedAtWork  ...  Laboratory Technician  Manager  \
# 4391                  4.0  ...                      0        0
# 1644                  5.0  ...                      0        0
# 6370                  1.0  ...                      0        0
# 9451                  2.0  ...                      0        0
# 11904                 2.0  ...                      0        1
# ...                   ...  ...                    ...      ...
# 1167                  4.0  ...                      0        0
# 11936                 5.0  ...                      0        0
# 2846                  1.0  ...                      0        0
# 11158                 5.0  ...                      0        0
# 1885                  1.0  ...                      0        0
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 4391                        0                  0                   0
# 1644                        0                  0                   1
# 6370                        0                  1                   0
# 9451                        0                  0                   0
# 11904                       0                  0                   0
# ...                       ...                ...                 ...
# 1167                        0                  0                   0
# 11936                       1                  0                   0
# 2846                        0                  0                   1
# 11158                       1                  0                   0
# 1885                        0                  0                   0
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 4391                 0                     0         0        0       1
# 1644                 0                     0         1        0       0
# 6370                 0                     0         1        0       0
# 9451                 0                     1         1        0       0
# 11904                0                     0         1        0       0
# ...                ...                   ...       ...      ...     ...
# 1167                 0                     1         0        1       0
# 11936                0                     0         0        0       1
# 2846                 0                     0         0        1       0
# 11158                0                     0         0        1       0
# 1885                 0                     0         0        0       1
#
# [11000 rows x 47 columns]

# %%
data= df_upsampled.sample(frac = 1)

# %%
X = data[['Age', 'AvgDailyHours', 'Education', 'HasFlexibleTimings',
       'IsIndividualContributor', 'JobInvolvement', 'JobSatisfaction',
       'LeavesTaken', 'MicromanagedAtWork', 'MonthlyIncome',
       'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'RemoteWorkSatistfaction',
       'SelfMotivationLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'WorkLoadLevel', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Human Resources',
       'Research & Development', 'Sales', 'Human Resources', 'Life Sciences',
       'Marketing', 'Medical', 'Other', 'Technical Degree', 'Female', 'Male',
       'Healthcare Representative', 'Human Resources', 'Laboratory Technician',
       'Manager', 'Manufacturing Director', 'Research Director',
       'Research Scientist', 'Sales Executive', 'Sales Representative',
       'Divorced', 'Married', 'Single']]

y = data['Target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=40)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (8800, 52) (8800,)
# Test set: (2200, 52) (2200,)

# %%
x_train
# Out:
#         Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 2147   33.0           6.82          3                   0
# 9772   54.0          18.02          1                   0
# 686    39.0          10.81          1                   0
# 184    36.0           6.20          5                   0
# 5141   57.0           9.20          2                   0
# ...     ...            ...        ...                 ...
# 11274  49.0           7.40          4                   0
# 6681   59.0           6.83          5                   0
# 8456   44.0          10.38          3                   1
# 8098   19.0           7.60          5                   1
# 6551   30.0           7.83          2                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 2147                         0               2                1          9.0
# 9772                         1               2                4         11.0
# 686                          0               2                3          6.0
# 184                          1               1                2         11.0
# 5141                         0               2                1          6.0
# ...                        ...             ...              ...          ...
# 11274                        0               2                1         15.0
# 6681                         1               1                3          5.0
# 8456                         0               3                2          3.0
# 8098                         0               2                4          6.0
# 6551                         1               4                4          7.0
#
#        MicromanagedAtWork  MonthlyIncome  ...  Laboratory Technician  Manager  \
# 2147                  1.0         133333  ...                      0        0
# 9772                  5.0          41667  ...                      0        0
# 686                   1.0         200000  ...                      0        0
# 184                   2.0         191667  ...                      0        0
# 5141                  2.0         200000  ...                      1        0
# ...                   ...            ...  ...                    ...      ...
# 11274                 3.0         241667  ...                      0        1
# 6681                  3.0         275000  ...                      0        0
# 8456                  3.0         316667  ...                      0        0
# 8098                  4.0          16667  ...                      1        0
# 6551                  2.0         133333  ...                      0        1
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 2147                        0                  0                   1
# 9772                        0                  0                   0
# 686                         0                  0                   0
# 184                         1                  0                   0
# 5141                        0                  0                   0
# ...                       ...                ...                 ...
# 11274                       0                  0                   0
# 6681                        0                  0                   0
# 8456                        0                  0                   0
# 8098                        0                  0                   0
# 6551                        0                  0                   0
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 2147                 0                     0         1        0       0
# 9772                 0                     0         0        0       1
# 686                  0                     0         0        1       0
# 184                  0                     0         0        0       1
# 5141                 0                     0         0        0       1
# ...                ...                   ...       ...      ...     ...
# 11274                0                     0         0        0       1
# 6681                 0                     0         0        1       0
# 8456                 0                     0         1        0       0
# 8098                 0                     0         0        0       1
# 6551                 0                     0         1        0       0
#
# [8800 rows x 52 columns]

# %%
x_test
# Out:
#         Age  AvgDailyHours  Education  HasFlexibleTimings  \
# 7435   59.0          18.34          3                   0
# 1310   59.0           9.32          2                   0
# 8732   31.0          18.02          3                   0
# 10662  29.0           6.87          5                   0
# 4774   21.0           7.68          1                   1
# ...     ...            ...        ...                 ...
# 1951   49.0          10.71          5                   0
# 8973   26.0           2.03          2                   1
# 11711  19.0           8.90          2                   0
# 1593   25.0           5.97          1                   0
# 11132  38.0           6.99          2                   0
#
#        IsIndividualContributor  JobInvolvement  JobSatisfaction  LeavesTaken  \
# 7435                         1               2                4         30.0
# 1310                         0               2                1         21.0
# 8732                         0               2                3         16.0
# 10662                        0               2                1          9.0
# 4774                         1               4                3         10.0
# ...                        ...             ...              ...          ...
# 1951                         1               2                1         12.0
# 8973                         1               3                1          2.0
# 11711                        1               3                1          3.0
# 1593                         0               3                1          6.0
# 11132                        0               1                2         10.0
#
#        MicromanagedAtWork  MonthlyIncome  ...  Laboratory Technician  Manager  \
# 7435                  3.0        7083330  ...                      0        0
# 1310                  2.0        6333330  ...                      0        0
# 8732                  1.0          33333  ...                      0        0
# 10662                 4.0         125000  ...                      1        0
# 4774                  1.0          58333  ...                      0        1
# ...                   ...            ...  ...                    ...      ...
# 1951                  4.0         283333  ...                      0        0
# 8973                  4.0          50000  ...                      0        0
# 11711                 3.0          25000  ...                      0        0
# 1593                  1.0          91667  ...                      1        0
# 11132                 2.0         100000  ...                      0        1
#
#        Manufacturing Director  Research Director  Research Scientist  \
# 7435                        0                  0                   0
# 1310                        1                  0                   0
# 8732                        1                  0                   0
# 10662                       0                  0                   0
# 4774                        0                  0                   0
# ...                       ...                ...                 ...
# 1951                        1                  0                   0
# 8973                        1                  0                   0
# 11711                       0                  1                   0
# 1593                        0                  0                   0
# 11132                       0                  0                   0
#
#        Sales Executive  Sales Representative  Divorced  Married  Single
# 7435                 0                     0         1        0       0
# 1310                 0                     0         1        0       0
# 8732                 0                     0         1        0       0
# 10662                0                     0         1        0       0
# 4774                 0                     0         0        0       1
# ...                ...                   ...       ...      ...     ...
# 1951                 0                     0         0        0       1
# 8973                 0                     0         0        1       0
# 11711                0                     0         0        1       0
# 1593                 0                     0         0        0       1
# 11132                0                     0         0        1       0
#
# [2200 rows x 52 columns]

# %%
y_train
# Out:
# 2147     1
# 9772     1
# 686      1
# 184      1
# 5141     1
#         ..
# 11274    0
# 6681     0
# 8456     0
# 8098     1
# 6551     0
# Name: Target, Length: 8800, dtype: int64

# %%
y_test
# Out:
# 7435     1
# 1310     1
# 8732     0
# 10662    1
# 4774     0
#         ..
# 1951     1
# 8973     1
# 11711    1
# 1593     1
# 11132    1
# Name: Target, Length: 2200, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import GridSearchCV

dept = [1, 5, 10, 50, 100, 500, 1000]
n_estimators =  [20, 40, 60, 80, 100, 120]


param_grid={'n_estimators':n_estimators , 'max_depth':dept}
clf = RandomForestClassifier()
model = GridSearchCV(clf,param_grid,scoring='accuracy',n_jobs=-1,cv=3)
model.fit(x_train,y_train)
print("optimal n_estimators",model.best_estimator_.n_estimators)
print("optimal max_depth",model.best_estimator_.max_depth)
optimal_n_estimators = model.best_estimator_.n_estimators
optimal_max_depth = model.best_estimator_.max_depth
# Out:
# optimal n_estimators 120
# optimal max_depth 500

# %%
#Testing AUC on Test data
rf = RandomForestClassifier(criterion='gini',max_depth = optimal_max_depth,n_estimators =700)

rf.fit(x_train,y_train)

#predict on test data and train data
 
y_predtest = rf.predict(x_test)
y_predtrain = rf.predict(x_train)

print('*'*35)

#accuracy on training and testing data

print('the accuracy on testing data',accuracy_score(y_test,y_predtest)*100)
print('the accuracy on training data',accuracy_score(y_train,y_predtrain)*100)
train1 = accuracy_score(y_train,y_predtrain)
test1 = accuracy_score(y_test,y_predtest)

print('*'*35)


# Code for drawing seaborn heatmaps
class_names = ['stress', 'composure']
cm = pd.DataFrame(confusion_matrix(y_test, y_predtest.round()), index=class_names, columns=class_names )
fig = m.figure( )
heatmap = s.heatmap(cm, annot=True, fmt="d")
# Out:
# ***********************************
# the accuracy on testing data 93.63636363636364
# the accuracy on training data 100.0
# ***********************************

# %%
all_model_result = pd.DataFrame(columns=[ 'Classifier' , 'Train-Accuracy', 'Test-Accuracy' ])
new = ['Random Forest',train1, test1]
all_model_result.loc[1] = new

# %%
#SUPPORT VECTOR MACHINE
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.calibration import CalibratedClassifierCV
import math
from sklearn.metrics import accuracy_score

C = [0.0001,0.001,0.01,0.1,1,10,100]

train_auc = []
cv_auc = []

for i in C:
    model = SVC(C=i,gamma=50) 
    clf = CalibratedClassifierCV(model, cv=3)
    clf.fit(x_train,y_train)
    prob_cv = clf.predict(x_test)
    cv_auc.append(accuracy_score(y_test,prob_cv))
    prob_train = clf.predict(x_train)
    train_auc.append(accuracy_score(y_train,prob_train))
optimal_C= C[cv_auc.index(max(cv_auc))]
C=[math.log(x) for x in C]

#plot auc vs alpha
x = plt.subplot( )
x.plot(C, train_auc, label='AUC train')
x.plot(C, cv_auc, label='AUC CV')
plt.title('AUC vs hyperparameter')
plt.xlabel('C')
plt.ylabel('AUC')
x.legend()
plt.show()

print('optimal C for which auc is maximum : ',optimal_C)
# Out:
# optimal C for which auc is maximum :  0.0001

# %%
gamma = [10,20,30,30,40]

train_auc = []
cv_auc = []

for i in gamma:
    model = SVC(C=1000,gamma=i) 
    clf = CalibratedClassifierCV(model, cv=3)
    clf.fit(x_train,y_train)
    prob_cv = clf.predict(x_test)
    cv_auc.append(accuracy_score(y_test,prob_cv))
    prob_train = clf.predict(x_train)
    train_auc.append(accuracy_score(y_train,prob_train))
optimal_gamma= gamma[cv_auc.index(max(cv_auc))]
# C=[math.log(x) for x in C]

#plot auc vs alpha
x = plt.subplot( )
x.plot(gamma, train_auc, label='AUC train')
x.plot(gamma, cv_auc, label='AUC CV')
plt.title('AUC vs hyperparameter')
plt.xlabel('gamma')
plt.ylabel('AUC')
x.legend()
plt.show()

print('optimal gamma for which auc is maximum : ',optimal_gamma)
# Out:
# optimal gamma for which auc is maximum :  10

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve

# %%
#Testing AUC on Test data
import pickle
svc = SVC(C=optimal_C,gamma=20)

svc.fit(x_train,y_train)


#predict on test data and train data
 
y_predtests = svc.predict(x_test)
y_predtrains = svc.predict(x_train)

print('*'*35)

#accuracy on training and testing data

print('the accuracy on testing data',accuracy_score(y_test,y_predtests))
print('the accuracy on training data',accuracy_score(y_train,y_predtrains))
train2 = accuracy_score(y_train,y_predtrains)
test2 = accuracy_score(y_test,y_predtests)

# Code for drawing seaborn heatmaps
class_names = ['stress', 'composure']
cm = pd.DataFrame(confusion_matrix(y_test, y_predtest.round()), index=class_names, columns=class_names )
fig = m.figure( )
heatmap = s.heatmap(cm, annot=True, fmt="d")
# Out:
# ***********************************
# the accuracy on testing data 0.4818181818181818
# the accuracy on training data 0.5045454545454545

# %%
new = ['SVM Classifier',train2, test2]
all_model_result.loc[2] = new

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import GridSearchCV

dept = [1, 5, 10, 50, 100, 500, 1000]
n_estimators =  [20, 40, 60, 80, 100, 120]

model=GradientBoostingClassifier()
param_grid={'n_estimators':n_estimators , 'max_depth':dept}
# clf = RandomForestClassifier()
model = GridSearchCV(model,param_grid,scoring='accuracy',n_jobs=-1,cv=3)
model.fit(x_train,y_train)
print("optimal n_estimators",model.best_estimator_.n_estimators)
print("optimal max_depth",model.best_estimator_.max_depth)
optimal_n_estimators = model.best_estimator_.n_estimators
optimal_max_depth = model.best_estimator_.max_depth
# Out:
# optimal n_estimators 120
# optimal max_depth 10

# %%
 #gradientboosting
import pickle
model = GradientBoostingClassifier(n_estimators=120,max_depth=10)
model.fit(x_train,y_train)

#predict on test data and train data
 
y_predtests = model.predict(x_test)
y_predtrains = model.predict(x_train)

print('*'*35)

#accuracy on training and testing data

print('the accuracy on testing data',accuracy_score(y_test,y_predtests))
print('the accuracy on training data',accuracy_score(y_train,y_predtrains))
train3 = accuracy_score(y_train,y_predtrains)
test3 = accuracy_score(y_test,y_predtests)

# Code for drawing seaborn heatmaps
class_names = ['stress', 'composure']
cm = pd.DataFrame(confusion_matrix(y_test, y_predtest.round()), index=class_names, columns=class_names )
fig = m.figure( )
heatmap = s.heatmap(cm, annot=True, fmt="d")
# Out:
# ***********************************
# the accuracy on testing data 0.9268181818181818
# the accuracy on training data 1.0

# %%
new = ['GradientBoosting Classifier',train3, test3]
all_model_result.loc[3] = new

# %%
all_model_result
# Out:
#                     Classifier  Train-Accuracy  Test-Accuracy
# 1                Random Forest        1.000000       0.936364
# 2               SVM Classifier        0.504545       0.481818
# 3  GradientBoosting Classifier        1.000000       0.926818
